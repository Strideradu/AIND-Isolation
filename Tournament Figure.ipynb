# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

result = [[0.9, 0.925,0.925,0.95],
          [0.55, 0.675, 0.575, 0.625],
          [28/40, 26/40, 27/40, 27/40],
          [23/40, 22/40, 22/40, 24/40],
          [20/40, 18/40, 20/40, 17/40],
          [22/40, 16/40, 24/40, 22/40],
          [20/40, 20/40, 17/40, 22/40]
         ]
x_label = ["AB_Improved", "AB_Custom", "AB_Custom2", "AB_Custom3"]
y_label = ["Random", "MM_Open", "MM_Center", "MM_Improved","AB_Open", "AB_Centered", "AB_Improved"]
ax = sns.heatmap(result, annot=True, linewidths=.5, cmap="YlGnBu", xticklabels = x_label,yticklabels = y_label)
plt.show()
